# %% [markdown]
# The n-queens puzzle is the problem of placing n queens on an n×n chessboard such that no two queens attack each other.
#
# Given an integer n, return all distinct solutions to the n-queens puzzle.
#
# Each solution contains a distinct board configuration of the n-queens' placement, where 'Q' and '.' both indicate a queen and an empty space respectively.
#
# Example:
#
# > Input: 4
#
# > Output: [
#
# > [".Q..",  // Solution 1
#
# >   "...Q",
#
# >   "Q...",
#
# >   "..Q."],
#
# > ["..Q.",  // Solution 2
#
# >   "Q...",
#
# >   "...Q",
#
# >   ".Q.."]
#
# > ]
#
# > Explanation: There exist two distinct solutions to the 4-queens puzzle as shown above.

# %%
class Solution:
    def solveNQueens(self, n):
        """
        :type n: int
        :rtype: List[List[str]]
        """
        result = []
        
        numStr = ''.join([str(i) for i in range(n)])
        totalColIndex = self.Permutation(numStr)
        for colidx in totalColIndex:
            if self.judge(colidx):
                solution = []
                for col in colidx:
                    solution.append('.' * int(col) + 'Q' + '.' * (n - int(col) - 1))
                result.append(solution)
        return result
    
    
    def Permutation(self, s):
        if not s or len(s) <= 0:
            return []
        
        if len(s) == 1:
            return list(s)
        
        result = []
        for i in range(len(s)):
            restStr = s[:i] + s[i+1:]
            restPerm = self.Permutation(restStr)
            for p in restPerm:
                if s[i] + p not in result:
                    result.append(s[i] + p)
        return result
    
    def judge(self, colidx):
        length = len(colidx)
        for i in range(length):
            for j in range(length):
                if i == j:
                    continue
                if i - j == (int(colidx[i]) - int(colidx[j])) or j - i == (int(colidx[i]) - int(colidx[j])):
                    return False
        return True

# %%
s = Solution()
s.solveNQueens(8)
# Out:
# [['Q.......',
#   '....Q...',
#   '.......Q',
#   '.....Q..',
#   '..Q.....',
#   '......Q.',
#   '.Q......',
#   '...Q....'],
#  ['Q.......',
#   '.....Q..',
#   '.......Q',
#   '..Q.....',
#   '......Q.',
#   '...Q....',
#   '.Q......',
#   '....Q...'],
#  ['Q.......',
#   '......Q.',
#   '...Q....',
#   '.....Q..',
#   '.......Q',
#   '.Q......',
#   '....Q...',
#   '..Q.....'],
#  ['Q.......',
#   '......Q.',
#   '....Q...',
#   '.......Q',
#   '.Q......',
#   '...Q....',
#   '.....Q..',
#   '..Q.....'],
#  ['.Q......',
#   '...Q....',
#   '.....Q..',
#   '.......Q',
#   '..Q.....',
#   'Q.......',
#   '......Q.',
#   '....Q...'],
#  ['.Q......',
#   '....Q...',
#   '......Q.',
#   'Q.......',
#   '..Q.....',
#   '.......Q',
#   '.....Q..',
#   '...Q....'],
#  ['.Q......',
#   '....Q...',
#   '......Q.',
#   '...Q....',
#   'Q.......',
#   '.......Q',
#   '.....Q..',
#   '..Q.....'],
#  ['.Q......',
#   '.....Q..',
#   'Q.......',
#   '......Q.',
#   '...Q....',
#   '.......Q',
# ...
